# %%
from llama_index.llms.ollama import Ollama

# %%
llm = Ollama(model="llama3.1:latest", request_timeout=120.0)

# %%
resp = llm.complete("What is BRC?")

# %%
print(resp)
# Out:
# BRC can stand for a few different things, but I'll cover the most common interpretations:
#
# 1. **British Royal Charter**: In the UK, BRC refers to the British Royal Charter, which grants universities or institutions certain privileges and powers.
# 2. **Blaschke Reaction Concentration**: In chemistry, BRC is an analytical technique that measures the concentration of a substance in a sample based on its reaction with another compound.
# 3. **Brady-Ryder Classification**: In some medical contexts, BRC refers to a system for categorizing patients with certain conditions or diseases.
#
# However, I suspect you might be thinking of:
#
# ...

# %%
resp = llm.complete("what are the Bowery Residents Committee (BRC) Leave Administration Guidelines")

# %%
print(resp)
# Out:
# The Bowery Residents' Committee (BRC) is a non-profit organization that provides housing and services to vulnerable populations in New York City. Their Leave Administration Guidelines are a set of rules governing when and how residents can take leave from their residency.
#
# I don't have access to specific content but I can guide you on where to find this information.
#
# To find the most up-to-date information, you may want to visit BRC's official website or contact them directly. They should be able to provide you with a copy of their Leave Administration Guidelines or point you in the direction of someone who can help.
#
# Alternatively, you can try searching for "BRC Leave Administration Guidelines" along with any relevant keywords (e.g., "2022", "pdf") on search engines like Google.
#
# ...

# %%
from llama_index.core import Settings
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

# %%
Settings.llm = llm
Settings.embed_model = HuggingFaceEmbedding(
    model_name="BAAI/bge-small-en-v1.5"
)
documents = SimpleDirectoryReader("/Users/gustavoramirez/Documents/Fall_2024/BTTAI/BRC/data").load_data()
index = VectorStoreIndex.from_documents(documents)
query_engine = index.as_query_engine()

# %%
print(documents)
# Out:
# [Document(id_='cd17f116-9361-46e4-8113-469b44b8a19a', embedding=None, metadata={'page_label': '1', 'file_name': 'Bowery Residents Committee (BRC) Leave Administration Guidelines.pdf', 'file_path': '/Users/gustavoramirez/Documents/Fall_2024/BTTAI/BRC/data/Bowery Residents Committee (BRC) Leave Administration Guidelines.pdf', 'file_type': 'application/pdf', 'file_size': 64201, 'creation_date': '2024-10-15', 'last_modified_date': '2024-10-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Bowery\nResidents\nCommittee\n(BRC)Leave\nAdministration\nGuidelines\nIntroduction\nBowery\nResidents\nCommittee\n(BRC)\nprovides\nvarious\ntypes\nof\nleave\nto\nsupport\nemployees\nin\nbalancing\ntheir\nwork\nand\npersonal\nresponsibilities.\nThis\nsection\noutlines\
# ...

# %%
response = query_engine.query("What is BRC?")
print(response)
# Out:
# A professional organization that provides various resources and support for its employees' development and well-being. It offers training programs, mentorship opportunities, leadership development initiatives, and career counseling services to help employees grow both personally and professionally. The organization also has a human resources department (HR) that handles employee relations, including reporting workplace issues and conflicts.

# %%
response = query_engine.query("What does BRC stand for, as provided in the leave admin guidelines doc?")
print(response)
# Out:
# Bowery Residents Committee.

# %%
response = llm.complete("what are some types of leave available for employees of bowery residents committee, be specific, based on the leave administration guidelines document provided?")
print(response)
# Out:
# I don't have access to a document labeled "Leave Administration Guidelines Document" from Bowery Residents Committee. I'm unable to provide information based on something that I cannot see or access. However, I can tell you that many organizations, including non-profits like Bowery Residents Committee, offer various types of leave under different circumstances and policies. Some common types of leaves include:
#
# 1. **Vacation Leave**: Paid time off for employees to rest, travel, or pursue personal interests.
# 2. **Sick Leave**: Time off granted when an employee is ill, injured, or needs medical care.
# 3. **Family and Medical Leave Act (FMLA) Leave**: A federal law requiring certain employers to provide eligible employees with unpaid leave for specified family and medical reasons, such as a serious health condition of the employee, a new child, or caring for a family member with a serious health condition.
# ...
